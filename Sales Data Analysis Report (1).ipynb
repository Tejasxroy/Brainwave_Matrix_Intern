# %% [markdown]
# # Customers Demographic Analysis¶
# We will analyze sales by demographic Analysis of customers eg city, age, gender .. The goal of this process is to give more information about our data so that the marketing team prepares to intensify the efficiency based on the data and information we will provide !
# At the end of this intention there is a challenge or duty you have to complete the end you have to understand all the facts that have already occurred and all the facts that I did not mention some and listed as a story you have to tell every part even if simple Ithakk to make a full page as a full report on this subject, From this core is teaching you how exploratory analysis is how you tell stories how to make information in your mind
#
# ### Gender
# ### Age
# ### City
# ### Stability
# ### Occupation
# ### Products

# %% [markdown]
# # 1. Import Libraries

# %%
# Importing the libraries which will be helpful for the data analysis.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Data Preparation

# %%
# Import the Dataset which we used for the modelling
dataset = pd.read_csv(r"D:\BlackFriday.csv\BlackFriday.csv")

# %% [markdown]
# # 3. Understand the Data

# %%
# Here are the few commands which will help us to understand the basics data 
# The info command will help us to understand the diffrent column present in the dataset and its datatype

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
#Len Command will help us understand the total number of records present in the dataset
len(dataset)
# Out:
# 537577

# %%
#.columns command will help us understand the columns present in the dataset
dataset.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
# The below command is help us to understand the total number of columns present in the datset
len(dataset.columns)
# Out:
# 12

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %% [markdown]
# # 3.Exploratory Data Analysis

# %% [markdown]
# ## 3.1. Gender

# %%
explode = (0.1,0)
fig1, ax1 = plt.subplots(figsize=(12,7))
ax1.pie(dataset["Gender"].value_counts(),explode=explode,labels=["Male","Female"], 
        autopct="%1.1f%%",shadow=True, startangle=90)
#Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
plt.tight_layout()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=dataset,x="Gender",palette="rainbow")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Men's purchasing power is greater than women's purchasing power, even in normal circumstances. This is likely to affect the owner of the money, but there has been a high turnout of men in the store. About 75% of the customers have made sales of men of all ages, The men are generally heading toward products at 8000 - 12,000, we have probably made sales worth more than 4 billion in men and more than 1 billion in ladies

# %% [markdown]
# ## 3.2. Age

# %%
plt.figure(figsize=(12,6))
sns.countplot(dataset["Age"],palette="rainbow")
plt.show()

# %% [markdown]
# #### Obviously, we can consider that the target age group of our stores is the age group of 26-35 years, we have achieved sales of more than 3 billion in the age group of 26-45 years

# %% [markdown]
# ## 3.3. City

# %%
explode = [0.1,0,0]
fig1, ax1 = plt.subplots(figsize=(12,7))
ax1.pie(dataset["City_Category"].value_counts(),explode=explode,
             labels=dataset["City_Category"].unique(), autopct="%1.1f%%", shadow=True, 
              startangle=90)
ax1.axis("equal")
plt.tight_layout()
plt.legend()
plt.show()

# %%
explode = [0.1,0,0]
fig1, ax1 = plt.subplots(figsize=(12,6))
ax1.pie(dataset.groupby("City_Category")["Purchase"].sum(), explode=explode, labels=dataset["City_Category"].unique(),
                   shadow=True, autopct="%1.1f%%",startangle=90)
# Equal aspcet ratio that pie is drwan as a circle
ax1.axis("equal")
plt.tight_layout()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=dataset,x="City_Category",palette="rainbow")
plt.show()

# %% [markdown]
# ### Unexpectedly, the highest sales do not come in the number of purchases, people from Area B have a greater purchasing power than others, and greater sales gained from people from Area C

# %% [raw]
# Look at the comments, sometimes we have to identify the appropriate wording and not mix with it as I did here. I would like to point out that sales do not reflect purchasing power, but the number of attendees reflects purchasing power because the data are individual sales. sales in the city, it reflects the purchasing power ..

# %% [markdown]
# # 3.4. Marital Stauts

# %%
explode = [0.1,0]
fig1, ax1 = plt.subplots(figsize=(12,6))
ax1.pie(dataset["Marital_Status"].value_counts(), explode=explode, labels=["Yes","No"],
                   shadow=True, autopct="%1.1f%%", startangle=90)
# Expect ratio ensure that the pie is drawn as a circle
ax1.axis("equal")
plt.tight_layout()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=dataset,x="Marital_Status",palette="rainbow")
plt.title("Distribution of Marital Status")
plt.show()

# %% [markdown]
# ### Most of our customers are more than 60% married, I see that the strategy of targeting families to ensure more clients succeed

# %% [markdown]
# # 3.5. Stability

# %%
labels=["First Year","Second Year","Third Year","More than Four Year","Guest"]
explode=[0.1,0.1,0,0,0]
fi1, ax1 = plt.subplots(figsize=(12,6))
ax1.pie(dataset.groupby("Stay_In_Current_City_Years")["Purchase"].sum(), explode=explode, labels=labels,
            shadow=True, autopct="%1.1f%%", startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis("equal")
plt.tight_layout()
plt.legend()

# %%
labels=["First Year","Second Year","Third Year","More than Four Year","Guest"]
explode=[0.1,0.1,0,0,0]
fi1, ax1 = plt.subplots(figsize=(12,6))
ax1.pie(dataset["Stay_In_Current_City_Years"].value_counts(), explode=explode, labels=labels,
            shadow=True, autopct="%1.1f%%", startangle=90)
ax1.axis("equal")
plt.tight_layout()
plt.legend()

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=dataset,x="Stay_In_Current_City_Years",palette="rainbow")
plt.show()

# %% [markdown]
# ### We have worked hard in the past two years and have achieved a large percentage of sales from the new population of cities, but these figures indicate that the older city dwellers have less passion for our products. I do not know in fact look at it for yourselves why old city dwellers did not achieve higher sales of the population New visitors or visitors from outside the city?
# We have almost gained about 1.75 billion new city residents only!

# %% [markdown]
# # 3.6. Occupation

# %%
fig1, ax1 = plt.subplots(figsize=(12,6))
occupation_counts = dataset["Occupation"].value_counts().sort_values()
colors = plt.cm.rainbow(np.linspace(0, 1, len(occupation_counts)))
occupation_counts.plot(kind="bar",color=colors)
# Out:
# <Axes: xlabel='Occupation'>

# %%
def plot(group,column,kind):
    ax=plt.figure(figsize=(12,6))
    grouped_data = dataset.groupby(group)[column].sum().sort_values()
    colors = plt.cm.rainbow(np.linspace(0,1,len(grouped_data)))
    grouped_data.plot(kind="bar",color=colors)
    
plot('Occupation','Purchase','bar')

# %% [markdown]
# ### We also note here that purchasing power is closely related to the Occupation in some cases as the first class of the table but there are some differences we will notice when checking the number of purchases and the value of those purchases total

# %% [markdown]
# # 3.7 Product and Categories

# %%
def plot(group,column,kind):
    ax =plt.figure(figsize=(12,6))
    grouped_data = dataset.groupby(group)[column].sum().sort_values()
    colors = plt.cm.rainbow(np.linspace(0,1,len(grouped_data)))
    grouped_data.plot(kind="bar",color=colors)

plot("Product_Category_1","Purchase","kind")

# %%
plot("Product_Category_2","Purchase","kind")

# %%
plot("Product_Category_3","Purchase","kind")

# %%
fig1, ax1 = plt.subplots(figsize=(12,7))
grouped_data = dataset.groupby("Product_ID")["Purchase"].count().nlargest(10).sort_values()
color=plt.cm.rainbow(np.linspace(0,1,len(grouped_data)))
grouped_data.plot(kind="bar",color=colors)
# Out:
# <Axes: xlabel='Product_ID'>

# %%
fig1, ax1 = plt.subplots(figsize=(12,7))
grouped_data = dataset.groupby("Product_ID")["Purchase"].sum().nlargest(10).sort_values()
color=plt.cm.rainbow(np.linspace(0,1,len(grouped_data)))
grouped_data.plot(kind="bar",color=colors)
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# ### Well, now we have the top 10 products for the top 10 profits , and first 10 category for each products .
